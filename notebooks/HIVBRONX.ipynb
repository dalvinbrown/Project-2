# %%
import pandas as pd 
import requests

# %%
HIVREPORT = pd.read_csv('../data/HIVREPORT.csv')

# %%
CASES = pd.DataFrame(HIVREPORT)

# %%
CASES
# Out:
#       Year        Borough          UHF       Gender      Age  \
# 0     2011            All          All          All      All
# 1     2011            All          All         Male      All
# 2     2011            All          All       Female      All
# 3     2011            All          All  Transgender      All
# 4     2011            All          All       Female  13 - 19
# ...    ...            ...          ...          ...      ...
# 6000  2015  Staten Island  Willowbrook         Male      All
# 6001  2015  Staten Island  Willowbrook         Male      All
# 6002  2015  Staten Island  Willowbrook         Male      All
# 6003  2015  Staten Island  Willowbrook         Male      All
# 6004  2015  Staten Island  Willowbrook         Male      All
#
#                         Race  HIV diagnoses  HIV diagnosis rate  \
# 0                        All           3379                48.3
# 1                        All           2595                79.1
# ...

# %%
CASES.isnull().values.any()
# Out:
# False

# %%
type(CASES['Borough'][0])
# Out:
# str

# %%
type(CASES['HIV diagnosis rate'][0])
# Out:
# numpy.float64

# %%
type(CASES
    )
# Out:
# pandas.core.frame.DataFrame

# %%
CASES.columns.dtype
# Out:
# dtype('O')

# %%
CASES.dtypes
# Out:
# Year                                  int64
# Borough                              object
# UHF                                  object
# Gender                               object
# Age                                  object
# Race                                 object
# HIV diagnoses                         int64
# HIV diagnosis rate                  float64
# Concurrent diagnoses                  int64
# % linked to care within 3 months      int64
# AIDS diagnoses                        int64
# AIDS diagnosis rate                 float64
# PLWDHI prevalence                   float64
# % viral suppression                   int64
# Deaths                                int64
# Death rate                          float64
# HIV-related death rate              float64
# Non-HIV-related death rate          float64
# dtype: object

# %%
CASES.loc[CASES['Year'] == 2015]
# Out:
#       Year        Borough          UHF       Gender      Age  \
# 4804  2015            All          All          All      All
# 4805  2015            All          All         Male      All
# 4806  2015            All          All       Female      All
# 4807  2015            All          All  Transgender      All
# 4808  2015            All          All       Female  13 - 19
# ...    ...            ...          ...          ...      ...
# 6000  2015  Staten Island  Willowbrook         Male      All
# 6001  2015  Staten Island  Willowbrook         Male      All
# 6002  2015  Staten Island  Willowbrook         Male      All
# 6003  2015  Staten Island  Willowbrook         Male      All
# 6004  2015  Staten Island  Willowbrook         Male      All
#
#                         Race  HIV diagnoses  HIV diagnosis rate  \
# 4804                     All           2490                34.5
# 4805                     All           2007                59.1
# ...

# %%
CASES_2015 = CASES[CASES['Year']==2015]

# %%
CASES_2015
# Out:
#       Year        Borough          UHF       Gender      Age  \
# 4804  2015            All          All          All      All
# 4805  2015            All          All         Male      All
# 4806  2015            All          All       Female      All
# 4807  2015            All          All  Transgender      All
# 4808  2015            All          All       Female  13 - 19
# ...    ...            ...          ...          ...      ...
# 6000  2015  Staten Island  Willowbrook         Male      All
# 6001  2015  Staten Island  Willowbrook         Male      All
# 6002  2015  Staten Island  Willowbrook         Male      All
# 6003  2015  Staten Island  Willowbrook         Male      All
# 6004  2015  Staten Island  Willowbrook         Male      All
#
#                         Race  HIV diagnoses  HIV diagnosis rate  \
# 4804                     All           2490                34.5
# 4805                     All           2007                59.1
# ...

# %%
CASES
# Out:
#       Year        Borough          UHF       Gender      Age  \
# 0     2011            All          All          All      All
# 1     2011            All          All         Male      All
# 2     2011            All          All       Female      All
# 3     2011            All          All  Transgender      All
# 4     2011            All          All       Female  13 - 19
# ...    ...            ...          ...          ...      ...
# 6000  2015  Staten Island  Willowbrook         Male      All
# 6001  2015  Staten Island  Willowbrook         Male      All
# 6002  2015  Staten Island  Willowbrook         Male      All
# 6003  2015  Staten Island  Willowbrook         Male      All
# 6004  2015  Staten Island  Willowbrook         Male      All
#
#                         Race  HIV diagnoses  HIV diagnosis rate  \
# 0                        All           3379                48.3
# 1                        All           2595                79.1
# ...

# %%
CASES_YEARBX = CASES_2015[CASES_2015['Borough']=='Bronx']

# %%
CASES_YEARBX
# Out:
#       Year Borough                   UHF  Gender      Age  \
# 4830  2015   Bronx                   All     All      All
# 4831  2015   Bronx                   All  Female  13 - 19
# 4832  2015   Bronx                   All  Female  20 - 29
# 4833  2015   Bronx                   All  Female  30 - 39
# 4834  2015   Bronx                   All  Female  40 - 49
# ...    ...     ...                   ...     ...      ...
# 5025  2015   Bronx  Pelham - Throgs Neck    Male      All
# 5026  2015   Bronx  Pelham - Throgs Neck    Male      All
# 5027  2015   Bronx  Pelham - Throgs Neck    Male      All
# 5028  2015   Bronx  Pelham - Throgs Neck    Male      All
# 5029  2015   Bronx  Pelham - Throgs Neck    Male      All
#
#                         Race  HIV diagnoses  HIV diagnosis rate  \
# 4830                     All            500                42.3
# 4831                     All              6                 8.8
# 4832                     All             37                30.1
# ...

# %%
CASES_YEARBXBLK = CASES_YEARBX[CASES_YEARBX['Race']=='Black']

# %%
CASES_YEARBXBLK
# Out:
#       Year Borough                       UHF  Gender  Age   Race  \
# 4839  2015   Bronx                       All  Female  All  Black
# 4851  2015   Bronx                       All    Male  All  Black
# 4864  2015   Bronx         Crotona - Tremont  Female  All  Black
# 4876  2015   Bronx         Crotona - Tremont    Male  All  Black
# 4889  2015   Bronx      Fordham - Bronx Park  Female  All  Black
# 4901  2015   Bronx      Fordham - Bronx Park    Male  All  Black
# 4914  2015   Bronx  High Bridge - Morrisania  Female  All  Black
# 4926  2015   Bronx  High Bridge - Morrisania    Male  All  Black
# 4939  2015   Bronx  Hunts Point - Mott Haven  Female  All  Black
# 4952  2015   Bronx  Hunts Point - Mott Haven    Male  All  Black
# 4965  2015   Bronx   Kingsbridge - Riverdale  Female  All  Black
# 4977  2015   Bronx   Kingsbridge - Riverdale    Male  All  Black
# 4989  2015   Bronx           Northeast Bronx  Female  All  Black
# ...

# %%
hiv_final = CASES_YEARBXBLK[CASES_YEARBXBLK['Gender']=='Male']

# %%
hiv_final
# Out:
#       Year Borough                       UHF Gender  Age   Race  \
# 4851  2015   Bronx                       All   Male  All  Black
# 4876  2015   Bronx         Crotona - Tremont   Male  All  Black
# 4901  2015   Bronx      Fordham - Bronx Park   Male  All  Black
# 4926  2015   Bronx  High Bridge - Morrisania   Male  All  Black
# 4952  2015   Bronx  Hunts Point - Mott Haven   Male  All  Black
# 4977  2015   Bronx   Kingsbridge - Riverdale   Male  All  Black
# 5001  2015   Bronx           Northeast Bronx   Male  All  Black
# 5026  2015   Bronx      Pelham - Throgs Neck   Male  All  Black
#
#       HIV diagnoses  HIV diagnosis rate  Concurrent diagnoses  \
# 4851            161               102.9                    34
# 4876             39               171.3                     5
# 4901             27               111.3                     9
# 4926             31               114.1                     7
# 4952             19               153.9                     6
# ...

# %%
hiv_final.to_csv('../output/HIVFinal.csv', index=False)
